# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/'PG WEB profe icochea'/Paita_proyecto/
# Out:
# /content/drive/MyDrive/PG WEB profe icochea/Paita_proyecto

# %%
ls
# Out:
# 'linea bayovar 220327-01.asc'  'linea bayovar 220327-02.hdr'
# 'linea bayovar 220327-01.hdr'  'linea bayovar 220327-03.asc'
# 'linea bayovar 220327-02.asc'  'linea bayovar 220327-03.hdr'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##Linea bayovar 220327-01

# %%
data= np.loadtxt("linea bayovar 220327-01.asc")
data.shape
# Out:
# (340, 5)

# %%
df=pd.DataFrame(data)
df.to_excel('Linea_bayovar_220327-01.xlsx',index=False)

# %%
plt.plot(data[:,1],-data[:,0],'r',linewidth=1,marker='o',markersize=0.5) #temperatura
plt.plot(data[:,2],-data[:,0],'b',linewidth=1,marker='o',markersize=0.5) #oxigeno
plt.plot(data[:,4],-data[:,0],'y',linewidth=1,marker='o',markersize=0.5) #sal

# %%
from matplotlib.ticker import MultipleLocator
def make_patch_spines_invisible(ax):
    ax.set_frame_on(True)
    ax.patch.set_visible(False)
    for sp in ax.spines.values():
        sp.set_visible(False)

fig, host = plt.subplots(figsize=(5, 7))
fig.subplots_adjust(right=0.95)
#twinx() creates another axes sharing the x axis. We do this twice for 
#red and blue extra axes
par1 = host.twiny()
par2 = host.twiny()
# Offset the right spine of par2.  The ticks and label have already been
# placed on the right by twinx above.
par2.spines["top"].set_position(("axes", 1.1))
# Having been created by twinx, par2 has its frame off, so the line of its
# detached spine is invisible.  First, activate the frame but make the patch
# and spines invisible.
make_patch_spines_invisible(par2)
# Second, show the right spine.
par2.spines["top"].set_visible(True)
sali, = host.plot(data[:,4],-data[:,0],linewidth=1,marker='o',markersize=0.5, color='blue')
tempi, =par1.plot(data[:,1],-data[:,0],linewidth=1,marker='o',markersize=0.5, color='red')
oxi, =par2.plot(data[:,2],-data[:,0],linewidth=1,marker='o',markersize=0.5, color='black')

host.set_xlim(34.5,35)
host.set_xlabel('Salinidad')
host.set_ylabel('Profundidad')
par1.set_xlabel('Temperatura')
par2.set_xlabel('Oxigeno')

host.xaxis.label.set_color('blue')
par1.xaxis.label.set_color('red')
par2.xaxis.label.set_color('black')

tkw = dict(size=6, width=1.5)
minorLocatory = MultipleLocator(100)
minorLocatorx = MultipleLocator(10)
host.yaxis.set_minor_locator(minorLocatory)
host.xaxis.set_minor_locator(minorLocatorx)

minorLocatory = MultipleLocator(10)
par1.xaxis.set_minor_locator(minorLocatory)

minorLocatory = MultipleLocator(100)
par2.xaxis.set_minor_locator(minorLocatory)

host.tick_params(axis='x', colors='blue', **tkw)
par1.tick_params(axis='x', colors='red', **tkw)
par2.tick_params(axis='x', colors='black', **tkw)
host.tick_params(direction='in', **tkw)
plt.text(0.1, 0.5, "5º32.6'S - 81º17.95'W / 220327-01")
#plt.text(0.5, 0.5, '5ºS - 81º25.02W')

lines = [sali, tempi, oxi]

host.legend(lines, [l.get_label() for l in lines],fontsize=12, frameon=False,loc=1, bbox_to_anchor=(1.02,0.9))
plt.savefig('Linea_bayovar_220327-01'+'.png',
    format='png', dpi=600, transparent=False, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: The handle <matplotlib.lines.Line2D object at 0x7ff59d793310> has a label of '_line0' which cannot be automatically added to the legend.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: The handle <matplotlib.lines.Line2D object at 0x7ff59d7aa5d0> has a label of '_line0' which cannot be automatically added to the legend.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: The handle <matplotlib.lines.Line2D object at 0x7ff59d7aab10> has a label of '_line0' which cannot be automatically added to the legend.

# %% [markdown]
# ## Linea bayovar 220327-02

# %%
data= np.loadtxt("linea bayovar 220327-02.asc")
data.shape
# Out:
# (121, 5)

# %%
df=pd.DataFrame(data)
df.to_excel('Linea_bayovar_220327-02.xlsx',index=False)

# %%
plt.plot(data[:,1],-data[:,0],'r',linewidth=1,marker='o',markersize=0.5) #temperatura
plt.plot(data[:,2],-data[:,0],'b',linewidth=1,marker='o',markersize=0.5) #oxigeno
plt.plot(data[:,4],-data[:,0],'y',linewidth=1,marker='o',markersize=0.5) #sal

# %%
from matplotlib.ticker import MultipleLocator
def make_patch_spines_invisible(ax):
    ax.set_frame_on(True)
    ax.patch.set_visible(False)
    for sp in ax.spines.values():
        sp.set_visible(False)

fig, host = plt.subplots(figsize=(5, 7))
fig.subplots_adjust(right=0.95)
#twinx() creates another axes sharing the x axis. We do this twice for 
#red and blue extra axes
par1 = host.twiny()
par2 = host.twiny()
# Offset the right spine of par2.  The ticks and label have already been
# placed on the right by twinx above.
par2.spines["top"].set_position(("axes", 1.1))
# Having been created by twinx, par2 has its frame off, so the line of its
# detached spine is invisible.  First, activate the frame but make the patch
# and spines invisible.
make_patch_spines_invisible(par2)
# Second, show the right spine.
par2.spines["top"].set_visible(True)
sali, = host.plot(data[:,4],-data[:,0],linewidth=1,marker='o',markersize=0.5, color='blue')
tempi, =par1.plot(data[:,1],-data[:,0],linewidth=1,marker='o',markersize=0.5, color='red')
oxi, =par2.plot(data[:,2],-data[:,0],linewidth=1,marker='o',markersize=0.5, color='black')

host.set_xlim(34.5,35)
host.set_xlabel('Salinidad')
host.set_ylabel('Profundidad')
par1.set_xlabel('Temperatura')
par2.set_xlabel('Oxigeno')

host.xaxis.label.set_color('blue')
par1.xaxis.label.set_color('red')
par2.xaxis.label.set_color('black')

tkw = dict(size=6, width=1.5)
minorLocatory = MultipleLocator(100)
minorLocatorx = MultipleLocator(10)
host.yaxis.set_minor_locator(minorLocatory)
host.xaxis.set_minor_locator(minorLocatorx)

minorLocatory = MultipleLocator(10)
par1.xaxis.set_minor_locator(minorLocatory)

minorLocatory = MultipleLocator(100)
par2.xaxis.set_minor_locator(minorLocatory)

host.tick_params(axis='x', colors='blue', **tkw)
par1.tick_params(axis='x', colors='red', **tkw)
par2.tick_params(axis='x', colors='black', **tkw)
host.tick_params(direction='in', **tkw)
plt.text(1.1, 0.5, "5º31.64'S - 81º15.34'W /220327-02")
#plt.text(0.5, 0.5, '5ºS - 81º25.02W')

lines = [sali, tempi, oxi]

host.legend(lines, [l.get_label() for l in lines],fontsize=12, frameon=False,loc=1, bbox_to_anchor=(1.02,0.9))

plt.savefig('Linea_bayovar_220327-02'+'.png',
    format='png', dpi=600, transparent=False, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: The handle <matplotlib.lines.Line2D object at 0x7ff59d36aa90> has a label of '_line0' which cannot be automatically added to the legend.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: The handle <matplotlib.lines.Line2D object at 0x7ff59d37f890> has a label of '_line0' which cannot be automatically added to the legend.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: The handle <matplotlib.lines.Line2D object at 0x7ff59d37fdd0> has a label of '_line0' which cannot be automatically added to the legend.

# %% [markdown]
# ## Linea bayovar 220327-03

# %%
data= np.loadtxt("linea bayovar 220327-03.asc")
data.shape
# Out:
# (79, 5)

# %%
df=pd.DataFrame(data)
df.to_excel('Linea_bayovar_220327-03.xlsx',index=False)

# %%
plt.plot(data[:,1],-data[:,0],'r',linewidth=1,marker='o',markersize=0.5) #temperatura
plt.plot(data[:,2],-data[:,0],'b',linewidth=1,marker='o',markersize=0.5) #oxigeno
plt.plot(data[:,4],-data[:,0],'y',linewidth=1,marker='o',markersize=0.5) #sal

# %%
from matplotlib.ticker import MultipleLocator
def make_patch_spines_invisible(ax):
    ax.set_frame_on(True)
    ax.patch.set_visible(False)
    for sp in ax.spines.values():
        sp.set_visible(False)

fig, host = plt.subplots(figsize=(5, 7))
fig.subplots_adjust(right=0.95)
#twinx() creates another axes sharing the x axis. We do this twice for 
#red and blue extra axes
par1 = host.twiny()
par2 = host.twiny()
# Offset the right spine of par2.  The ticks and label have already been
# placed on the right by twinx above.
par2.spines["top"].set_position(("axes", 1.1))
# Having been created by twinx, par2 has its frame off, so the line of its
# detached spine is invisible.  First, activate the frame but make the patch
# and spines invisible.
make_patch_spines_invisible(par2)
# Second, show the right spine.
par2.spines["top"].set_visible(True)
sali, = host.plot(data[:,4],-data[:,0],linewidth=1,marker='o',markersize=0.5, color='blue')
tempi, =par1.plot(data[:,1],-data[:,0],linewidth=1,marker='o',markersize=0.5, color='red')
oxi, =par2.plot(data[:,2],-data[:,0],linewidth=1,marker='o',markersize=0.5, color='black')

host.set_xlim(34.5,35)
host.set_xlabel('Salinidad')
host.set_ylabel('Profundidad')
par1.set_xlabel('Temperatura')
par2.set_xlabel('Oxigeno')

host.xaxis.label.set_color('blue')
par1.xaxis.label.set_color('red')
par2.xaxis.label.set_color('black')

tkw = dict(size=6, width=1.5)
minorLocatory = MultipleLocator(100)
minorLocatorx = MultipleLocator(10)
host.yaxis.set_minor_locator(minorLocatory)
host.xaxis.set_minor_locator(minorLocatorx)

minorLocatory = MultipleLocator(10)
par1.xaxis.set_minor_locator(minorLocatory)

minorLocatory = MultipleLocator(100)
par2.xaxis.set_minor_locator(minorLocatory)

host.tick_params(axis='x', colors='blue', **tkw)
par1.tick_params(axis='x', colors='red', **tkw)
par2.tick_params(axis='x', colors='black', **tkw)
host.tick_params(direction='in', **tkw)
plt.text(2, 0.5, "5º28.99'S - 81º13.69'W / 220327-03")
#plt.text(0.5, 0.5, '5ºS - 81º25.02W')

lines = [sali, tempi, oxi]

host.legend(lines, [l.get_label() for l in lines],fontsize=12, frameon=False,loc=1, bbox_to_anchor=(1.02,0.9))

plt.savefig('Linea_bayovar_220327-03'+'.png',
    format='png', dpi=600, transparent=False, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: The handle <matplotlib.lines.Line2D object at 0x7ff59d36a1d0> has a label of '_line0' which cannot be automatically added to the legend.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: The handle <matplotlib.lines.Line2D object at 0x7ff59d565150> has a label of '_line0' which cannot be automatically added to the legend.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: The handle <matplotlib.lines.Line2D object at 0x7ff59d565710> has a label of '_line0' which cannot be automatically added to the legend.
